# %% [markdown]
# # Author : Santhosh M

# %% [markdown]
# # Task - 3: Exploratory Data Analysis
# ## Problem statement : As a business manager, try to find out the weak areas where you can work to make more profit.What all business problems you can derive by exploring the data?
# ## The Sparks Foundation (Graduate Rotational Internship Program (GRIP) June 2021 Batch)
#
# ## Data Science & Business Analytics Tasks

# %% [markdown]
# ## Importing the requried libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")

# %% [markdown]
# ## importing Dataset

# %%
df = pd.read_csv('SampleSuperstore (1).csv')
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# ### Checking the  summary of our data

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ### Checking for missing values

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df['City'].value_counts()
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Pico Rivera        1
# Ontario            1
# Cheyenne           1
# Springdale         1
# Redwood City       1
# Name: City, Length: 531, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# ### Checking for duplicate data

# %%
df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# ##### Dropping  the duplicate rows

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.nunique().sum()
# Out:
# 14381

# %% [markdown]
# ### Dropping the irrelevant columns

# %%
df.drop(['Postal Code'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### Checking the statistical relation between various rows and columns

# %% [markdown]
# ##### Covariance is when two variables vary with each other, whereas Correlation is when the change in one variable results in the change in  another variable..

# %%
df.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
df.cov()
# Out:
#                   Sales    Quantity   Discount        Profit
# Sales     388434.455308  278.459923  -3.627228  69944.096586
# Quantity     278.459923    4.951113   0.003961     34.534769
# Discount      -3.627228    0.003961   0.042622    -10.615173
# Profit     69944.096586   34.534769 -10.615173  54877.798055

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize  = (10,6))
sns.countplot(x='Ship Mode', data=df)
plt.show()

# %%
plt.figure(figsize  = (10,6))
sns.countplot(x='Segment', data=df)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x=df['State'])
plt.xticks(rotation=90)
plt.title('Count of State wise shipments')
plt.show()

# %% [markdown]
# ### Visualization  Understanding  of Count of State Wise Shipments :
#
# ##### State wise California has highest sales.
#
# ##### States like Texas, New York, etc are active in business.
#
# ##### Few states like North Dakota, Wyoming and West Virginia have less or no sales at all.
#
# ##### To generate more profit we have to increase our sales in Texas and New York where we have potential customers.

# %%
plt.figure(figsize = (10,7))
textprops = {"fontsize":20}
plt.title('Category')
plt.pie(df['Category'].value_counts(), labels=df['Category'].value_counts().index,autopct='%1.1f%%',textprops = textprops)
plt.show()

# %% [markdown]
# ##### This pie graph indicates that the  Office supplies have  the highest demand and others are comparatively less in demand

# %%
plt.figure(figsize = (10,6))
df.groupby('Region')['Profit'].agg(sum).plot(kind='bar',color = "red")
plt.ylabel('Profit')
plt.title('Profits in different regions')
plt.show()

# %% [markdown]
# ### Overview  Understannding of Profit in different Region Chart
#
# ##### West generates most of the profit followed by East.
#
# ##### Central and Southern region are generating less profit as compared to the Eastern and Western Region.
#
# ##### Increase the sales in Central and Southern region in order to generate more profit in these region.

# %%
sp = df.groupby('State')['Profit'].sum()
plt.figure(figsize=(16,8))
sns.barplot(x=sp.index, y=sp.values)
plt.xticks(rotation=90)
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ### the above graph is visualize california has higest profit

# %%
sns.pairplot(df, hue='Segment')

# %%
plt.figure(figsize = (9,5))
sns.heatmap(df.corr(), annot = True, linewidth = 5,linecolor = "blue", cbar = True, cmap = 'rocket_r')
# Out:
# <AxesSubplot:>

# %%
df.groupby(['Category'])[['Profit','Sales']].agg(sum).plot(kind='bar',figsize=(10,6), )
plt.ylabel('Profit and Sales')
plt.show()

# %% [markdown]
# ##### This shows  that Furniture is generating very less profit.

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Category',hue='Segment',data=df)
plt.ylabel('Count of Segment')
plt.title('Count of Segment by Category and Segment')
# Out:
# Text(0.5, 1.0, 'Count of Segment by Category and Segment')

# %% [markdown]
# ##### The highest purchases are in consumer segment whereas home office segment has the least purchases in each category. We need to focus on the corporate and home office segment as well to increase our sales and profit.

# %%
df.groupby('Sub-Category')[['Sales','Profit']].agg(sum).plot(kind='barh',figsize=(15, 8))
plt.ylabel('Sub-Category')
plt.xlabel('Sales and Profit')
plt.show()

# %% [markdown]
# ### The phones and chairs are has highest sales , phones and copiers are has higest profit

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='Region',hue='Ship Mode',data=df)
plt.ylabel('Count of Ship Mode')
plt.title('Count of ship mode by region and ship mode')
# Out:
# Text(0.5, 1.0, 'Count of ship mode by region and ship mode')

# %% [markdown]
# ##### Least sales are in Southern region, we can attract this region by offering more discount. Standard mode of shipment is opted by most of the customers in each region.

# %%
df.plot(kind = "scatter",figsize = (10,6), x = "Sales", y= "Profit", c = "Discount", s = 20,fontsize = 16, colormap = "viridis")
plt.ylabel('Total Profits',fontsize = 16)
plt.title("Interdependency of Sales,Profits and Discounts",fontsize = 16)
plt.show()

# %% [markdown]
# ### Weak Areas Where You Can Work To Make More Profit.
#
#
# ##### 1. We should limit the sales of furniture and increase that of office supplies and technology as it is generating very less profit as compared to its sales.
#
# ##### 2 The sales and profit in Southern and Central region are less so we should give more incentives like discount in order to increase sales, hence profit will increase.
#
# ##### 3 After the highest sales in California we have high value of potential customers in Texas and New York so we should concentrate more on these states to generate more profit.
#
# ##### 4 We have highest purchases in consumer segment but we should also concentrate on corporate and home office segments to increase our sales and profit.
#
# ##### 5 Few states like North Dakota, Wyoming and West Virginia have less or no sales at all so we also need to focus on these states.

# %% [markdown]
# # Thank you
